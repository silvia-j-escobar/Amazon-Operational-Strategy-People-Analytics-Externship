# %% [markdown]
# <a href="https://colab.research.google.com/github/silvia-j-escobar/Amazon-Operational-Strategy-People-Analytics-Externship/blob/main/ExploringGlassdoorDatasetwithPandas_Silvia_Escobar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# P2.S3.4 Explore the Glassdoor Dataset with Pandas

# %%
import pandas as pd

# %%
# Load the dataset
data = pd.read_csv('/content/glass_reviews_silviaescobar.csv')

# %%
# Preview the data
print(data.head())
# Out:
#    review_id               rating_date  count_helpful  count_unhelpful  \
# 0          1  2025-06-03T00:00:00.000Z              0                0
# 1          2  2025-05-29T00:00:00.000Z              0                0
# 2          3  2025-05-28T00:00:00.000Z              0                0
# 3          4  2025-05-26T00:00:00.000Z              0                0
# 4          5  2025-05-23T00:00:00.000Z              0                0
#
#    employee_length employee_status                       employee_type  \
# 0                0         REGULAR                    Current employee
# 1                1        CONTRACT  Current employee, less than 1 year
# 2                1         REGULAR  Current employee, less than 1 year
# 3                2       PART_TIME                   Current employees
# 4                0         REGULAR                    Current employee
#
#    flag_covid  flag_featured flags_business_outlook  ... review_advice  \
# ...

# %%
# Get info about the columns
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   review_id                     142 non-null    int64
#  1   rating_date                   142 non-null    object
#  2   count_helpful                 142 non-null    int64
#  3   count_unhelpful               142 non-null    int64
#  4   employee_length               142 non-null    int64
#  5   employee_status               140 non-null    object
#  6   employee_type                 142 non-null    object
#  7   flag_covid                    142 non-null    bool
#  8   flag_featured                 142 non-null    bool
#  9   flags_business_outlook        71 non-null     object
#  10  flags_ceo_approval            72 non-null     object
#  11  flags_recommend_frend         86 non-null     object
#  12  rating_culture_values         142 non-null    int64
# ...

# %%
# Check number of rows and columns
print(data.shape)
# Out:
# (142, 28)

# %%
# Get statistical summary of numeric columns
print(data.describe())
# Out:
#         review_id  count_helpful  count_unhelpful  employee_length  \
# count  142.000000          142.0            142.0       142.000000
# mean    71.500000            0.0              0.0         1.605634
# std     41.135953            0.0              0.0         2.265867
# min      1.000000            0.0              0.0         0.000000
# 25%     36.250000            0.0              0.0         0.000000
# 50%     71.500000            0.0              0.0         1.000000
# 75%    106.750000            0.0              0.0         2.000000
# max    142.000000            0.0              0.0        20.000000
#
#        rating_culture_values  rating_diversity_inclusion  rating_overall  \
# count             142.000000                  142.000000      142.000000
# mean                2.119718                    2.457746        3.204225
# std                 1.888684                    2.033839        1.381431
# ...
