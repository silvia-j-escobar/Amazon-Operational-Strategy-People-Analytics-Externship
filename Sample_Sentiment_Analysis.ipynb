# %% [markdown]
# <a href="https://colab.research.google.com/github/silvia-j-escobar/Amazon-Operational-Strategy-People-Analytics-Externship/blob/main/Sample_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.12/dist-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /usr/local/lib/python3.12/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (4.67.1)

# %%
from textblob import TextBlob
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/sample_cleaned_reviews.csv')
df
# Out:
#                                      cleaned_text
# 0                  supportive team great training
# 1   management helpful coworkers friendly culture
# 2              fast paced challenging environment
# 3                toxic manager poor communication
# 4               opportunity grow learn new skills
# 5                     long hours overtime burnout
# 6              love company mission positive vibe
# 7             underpaid overworked no recognition
# 8                 flexible schedule good benefits
# 9               lack transparency from leadership
# 10       great onboarding process helpful mentors
# 11         stressful shifts inconsistent policies
# 12            collaborative team regular feedback
# 13                  not enough growth opportunity
# 14                    excellent work life balance
# 15        micromanagement demotivating atmosphere
# 16          supportive managers focus development
# 17         unrealistic expectations poor planning
# 18          training resources outdated confusing
# 19            open communication regular checkins
# 20              leadership values employees input
# 21                     burnout high turnover rate
# 22             positive team energy solid support
# 23                   lack structure poor guidance
# 24       good learning curve mentorship available

# %%
df['sentiment_polarity'] = df['cleaned_text'].apply(lambda x: TextBlob(x).sentiment.polarity)
df['sentiment_subjectivity'] = df['cleaned_text'].apply(lambda x: TextBlob(x).sentiment.subjectivity)

# %%
def label_sentiment(score):
    if score > 0.1:
        return 'positive'
    elif score < -0.1:
        return 'negative'
    else:
        return 'neutral'

df['sentiment_label'] = df['sentiment_polarity'].apply(label_sentiment)
df
# Out:
#                                      cleaned_text  sentiment_polarity  \
# 0                  supportive team great training            0.650000
# 1   management helpful coworkers friendly culture            0.375000
# 2              fast paced challenging environment            0.350000
# 3                toxic manager poor communication           -0.400000
# 4               opportunity grow learn new skills            0.136364
# 5                     long hours overtime burnout           -0.050000
# 6              love company mission positive vibe            0.363636
# 7             underpaid overworked no recognition            0.000000
# 8                 flexible schedule good benefits            0.700000
# 9               lack transparency from leadership            0.000000
# 10       great onboarding process helpful mentors            0.800000
# 11         stressful shifts inconsistent policies            0.000000
# 12            collaborative team regular feedback            0.000000
# 13                  not enough growth opportunity            0.000000
# 14                    excellent work life balance            1.000000
# 15        micromanagement demotivating atmosphere            0.000000
# 16          supportive managers focus development            0.500000
# 17         unrealistic expectations poor planning           -0.450000
# 18          training resources outdated confusing           -0.350000
# 19            open communication regular checkins            0.000000
# 20              leadership values employees input            0.000000
# 21                     burnout high turnover rate            0.160000
# 22             positive team energy solid support            0.113636
# 23                   lack structure poor guidance           -0.400000
# 24       good learning curve mentorship available            0.550000
#
#     sentiment_subjectivity sentiment_label
# 0                 0.875000        positive
# 1                 0.500000        positive
# 2                 0.800000        positive
# 3                 0.600000        negative
# 4                 0.454545        positive
# 5                 0.400000         neutral
# 6                 0.572727        positive
# 7                 0.000000         neutral
# 8                 0.600000        positive
# 9                 0.000000         neutral
# 10                0.750000        positive
# 11                0.000000         neutral
# 12                0.076923         neutral
# 13                0.500000         neutral
# 14                1.000000        positive
# 15                0.000000         neutral
# 16                1.000000        positive
# 17                0.800000        negative
# 18                0.516667        negative
# 19                0.288462         neutral
# 20                0.000000         neutral
# 21                0.540000        positive
# 22                0.322727        positive
# 23                0.600000        negative
# 24                0.500000        positive

# %%
df['sentiment_label'].value_counts().plot(kind='bar', title="Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.show()

# %%
df['sentiment_label'].value_counts().plot(
    kind='pie',
    autopct='%1.0f%%',
    title="Sentiment Breakdown"
)
plt.ylabel('')
plt.show()
