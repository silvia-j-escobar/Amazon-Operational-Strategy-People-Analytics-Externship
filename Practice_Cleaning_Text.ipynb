# %% [markdown]
# <a href="https://colab.research.google.com/github/silvia-j-escobar/Amazon-Operational-Strategy-People-Analytics-Externship/blob/main/Practice_Cleaning_Text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import pandas
import pandas as pd

# %%
# Load the dataset
data= pd.read_csv('/content/sample_dirty_text.csv')

# %%
# Preview the data
print(data.head())
# Out:
#                      noisy_text
# 0        This JOB is AMAZING!!!
# 1         Worst. Manager. EVER.
# 2  pay is good, but hours? meh.
# 3     THE benefits are... okay.
# 4    I just don't know anymore.

# %%
# Get info about the columns
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   noisy_text  10 non-null     object
# dtypes: object(1)
# memory usage: 212.0+ bytes
# None

# %%
# Check number of rows and columns
print(data.shape)
# Out:
# (10, 1)

# %%
# Get statistical summary of numeric columns
print(data.describe())
# Out:
#                     noisy_text
# count                       10
# unique                      10
# top     This JOB is AMAZING!!!
# freq                         1

# %%
import nltk
import string
from nltk.corpus import stopwords
nltk.download('stopwords')

def clean_text(text):
    if pd.isnull(text):
        return ""
    tokens = text.lower().translate(str.maketrans('', '', string.punctuation)).split()
    return ' '.join([word for word in tokens if word not in stopwords.words('english')])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Import Required libraries
import re
from nltk.corpus import stopwords
import nltk

nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)   # remove punctuation & numbers
    words = text.split()
    words = [word for word in words if word not in stop_words]
    return " ".join(words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Clean text
data['cleaned_text'] = data['noisy_text'].apply(clean_text)

# %%
# Save Clean DataFrame
data.to_csv("sample_cleaned_text.csv", index=False)
