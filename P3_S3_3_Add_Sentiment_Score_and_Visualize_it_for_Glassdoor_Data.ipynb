# %% [markdown]
# <a href="https://colab.research.google.com/github/silvia-j-escobar/Amazon-Operational-Strategy-People-Analytics-Externship/blob/main/P3_S3_3_Add_Sentiment_Score_and_Visualize_it_for_Glassdoor_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.12/dist-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /usr/local/lib/python3.12/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (4.67.1)

# %%
from textblob import TextBlob
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/glassdoor_cleaned_text.csv')
df
# Out:
#                     summary_cleaned  \
# 0                            amazon
# 1                              good
# 2                   good experience
# 3                              dhdh
# 4                     good pay rate
# ..                              ...
# 136  badly managed poor advancement
# 137                 physical damage
# 138                  cog production
# 139  toxic leadershipculture abound
# 140             work hard make less
#
#                           advice_to_management_cleaned  \
# 0                                    dont micro manage
# 1                    remove attitude manager warehouse
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 136                   wont take like crisis management
# 137                                                NaN
# 138  better employee constantly go beyond help make...
# 139                                                NaN
# 140                                                NaN
#
#                                    review_pros_cleaned  \
# 0    interactive leave take whenever long time easy...
# 1                            good easy work enviorment
# 2                                   help grow good pay
# 3                          plenty work meet new people
# 4    good holiday pay additional benefits permanent...
# ..                                                 ...
# 136         health benefits day one flexible schedules
# 137                                 got discounts shop
# 138                         like busy youll alway busy
# 139  learn kinds fancy abbreviations metrics public...
# 140                           flexible time associates
#
#                                    review_cons_cleaned
# 0            inhumane draining physically amp mentally
# 1    sticks rules completing targets otherwise get ...
# 2    limited opportunities advancementno clear path...
# 3                           tough body labor intensive
# 4                  hiring permanent employees directly
# ..                                                 ...
# 136  management says team players department leads ...
# 137                       physical damage lot injuries
# 138  number doesnt matter worst best employee cliqu...
# 139  work life balance poor detroit looks rich popu...
# 140  work load huge paid especially youre reliable ...
#
# [141 rows x 4 columns]

# %%
df['sentiment_polarity'] = df['summary_cleaned'].apply(lambda x: TextBlob(x).sentiment.polarity)
df['sentiment_subjectivity'] = df['summary_cleaned'].apply(lambda x: TextBlob(x).sentiment.subjectivity)

# %%
def label_sentiment(score):
    if score > 0.1:
        return 'positive'
    elif score < -0.1:
        return 'negative'
    else:
        return 'neutral'

df['sentiment_label'] = df['sentiment_polarity'].apply(label_sentiment)
df
# Out:
#                     summary_cleaned  \
# 0                            amazon
# 1                              good
# 2                   good experience
# 3                              dhdh
# 4                     good pay rate
# ..                              ...
# 136  badly managed poor advancement
# 137                 physical damage
# 138                  cog production
# 139  toxic leadershipculture abound
# 140             work hard make less
#
#                           advice_to_management_cleaned  \
# 0                                    dont micro manage
# 1                    remove attitude manager warehouse
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 136                   wont take like crisis management
# 137                                                NaN
# 138  better employee constantly go beyond help make...
# 139                                                NaN
# 140                                                NaN
#
#                                    review_pros_cleaned  \
# 0    interactive leave take whenever long time easy...
# 1                            good easy work enviorment
# 2                                   help grow good pay
# 3                          plenty work meet new people
# 4    good holiday pay additional benefits permanent...
# ..                                                 ...
# 136         health benefits day one flexible schedules
# 137                                 got discounts shop
# 138                         like busy youll alway busy
# 139  learn kinds fancy abbreviations metrics public...
# 140                           flexible time associates
#
#                                    review_cons_cleaned  sentiment_polarity  \
# 0            inhumane draining physically amp mentally            0.000000
# 1    sticks rules completing targets otherwise get ...            0.700000
# 2    limited opportunities advancementno clear path...            0.700000
# 3                           tough body labor intensive            0.000000
# 4                  hiring permanent employees directly            0.700000
# ..                                                 ...                 ...
# 136  management says team players department leads ...           -0.550000
# 137                       physical damage lot injuries            0.000000
# 138  number doesnt matter worst best employee cliqu...            0.000000
# 139  work life balance poor detroit looks rich popu...            0.000000
# 140  work load huge paid especially youre reliable ...           -0.229167
#
#      sentiment_subjectivity sentiment_label
# 0                  0.000000         neutral
# 1                  0.600000        positive
# 2                  0.600000        positive
# 3                  0.000000         neutral
# 4                  0.600000        positive
# ..                      ...             ...
# 136                0.633333        negative
# 137                0.142857         neutral
# 138                0.000000         neutral
# 139                0.000000         neutral
# 140                0.304167        negative
#
# [141 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

df['sentiment_label'].value_counts().plot(kind='bar', title="Glassdoor Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Number of Reviews")
plt.show()

# %%
df['sentiment_label'].value_counts().plot(
    kind='pie',
    autopct='%1.0f%%',
    title="Glassdoor Sentiment Breakdown"
)
plt.ylabel('')
plt.show()

# %%
import matplotlib.pyplot as plt

df['sentiment_label'].value_counts().plot(kind='bar', title="Glassdoor Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Number of Reviews")
plt.show()
